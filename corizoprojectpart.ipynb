# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahcodess/Data-Science/blob/main/corizoprojectpart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3.  Data analysis & visualisation:

# %%
#importing packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/signal-data.csv')

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
data.describe()
# Out:
#                  0            1            2            3            4  \
# count  1561.000000  1560.000000  1553.000000  1553.000000  1553.000000
# mean   3014.452896  2495.850231  2200.547318  1396.376627     4.197013
# std      73.621787    80.407705    29.513152   441.691640    56.355540
# min    2743.240000  2158.750000  2060.660000     0.000000     0.681500
# 25%    2966.260000  2452.247500  2181.044400  1081.875800     1.017700
# 50%    3011.490000  2499.405000  2201.066700  1285.214400     1.316800
# 75%    3056.650000  2538.822500  2218.055500  1591.223500     1.525700
# max    3356.350000  2846.440000  2315.266700  3715.041700  1114.536600
#
#             5            6            7            8            9  ...  \
# count  1553.0  1553.000000  1558.000000  1565.000000  1565.000000  ...
# mean    100.0   101.112908     0.121822     1.462862    -0.000841  ...
# std       0.0     6.237214     0.008961     0.073897     0.015116  ...
# ...

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
#taking row and columns as cat and col
cat = []
num = []
for column in data.columns :
  if data[column].nunique() > 10:
    num.append(column)
  else:
    cat.append(column)

# %%
sns.distplot(data['1'])
# Out:
# <Axes: xlabel='1', ylabel='Density'>

# %%
sns.distplot(data['101'])
# Out:
# <Axes: xlabel='101', ylabel='Density'>

# %%
#skewed data
data['101'].skew()
# Out:
# -0.27581031715311927

# %% [markdown]
# BIVARIATE/MULTIVARIATE ANALYSIS

# %%
#Now taking multiple values (more than one)
sns.scatterplot(x='0', y='520', data=data)
# Out:
# <Axes: xlabel='0', ylabel='520'>

# %%
sns.boxplot(x='3', y='1', data=data)
#Due to a large dataset, the boxplot looks like this
# Out:
# <Axes: xlabel='3', ylabel='1'>

# %%
sns.barplot(x='303', y='520', hue='450', data=data)
# Out:
# <Axes: xlabel='303', ylabel='520'>

# %%
pd.crosstab(data['502'],data['30'])
#Now we will make a heatmap of this
# Out:
# 30   0.0341  0.0372  0.0434  0.0469  0.0728  0.0777  0.0810  0.0926  0.0927  \
# 502
# 0.0       1       1       1       1       1       2       1       1       1
#
# 30   0.0974  ...  0.2593  0.2596  0.2602  0.2608  0.2620  0.2691  0.2696  \
# 502          ...
# 0.0       1  ...       1       1       1       2       1       1       1
#
# 30   0.2732  0.2843  0.2851
# 502
# 0.0       1       1       1
#
# [1 rows x 840 columns]

# %%
sns.heatmap(pd.crosstab(data['502'],data['30']))
# Out:
# <Axes: xlabel='30', ylabel='502'>
